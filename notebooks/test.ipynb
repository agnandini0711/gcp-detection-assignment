# %%
from src.dataset import GCPDataset

dataset = GCPDataset(
    image_dir="../data/train_dataset",
    label_path="../data/curated_gcp_marks.json"
)

img, coords, shape = dataset[0]

print(img.shape)
print(coords)
print(shape)
# Out:
# torch.Size([3, 512, 512])
# tensor([0.6009, 0.3505])
# tensor(0)

# %%
import matplotlib.pyplot as plt

plt.imshow(img.permute(1,2,0))
plt.title(f"Shape class: {shape}")
plt.axis("off")
plt.show()

# %%
from src.model import GCPModel
import torch

model = GCPModel()

dummy = torch.randn(4,3,512,512)

coords, shape = model(dummy)

print(coords.shape)
print(shape.shape)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to C:\Users\HP/.cache\torch\hub\checkpoints\resnet18-f37072fd.pth
# 100.0%
# torch.Size([4, 2])
# torch.Size([4, 3])
